# %%
import datetime
import pytz
import xml.etree.ElementTree as ET
import numpy as np
import pandas as pd
from dateutil import parser
import matplotlib.pyplot as plt
import time
import re
start_time = time.time()

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

import bs4 as bs
import urllib.request
    
#%matplotlib inline

utc=pytz.UTC

#debug = True
debug = True
filepath = './sample_data/'

if debug == False:
    gpx_file = input('Enter file name (must be in same directory as this program for now): ')
    tree = ET.parse(filepath + gpx_file)
else:
    #tree = ET.parse('./sample_data/Exciter_100.gpx')
    tree = ET.parse('./sample_data/S4_Form_Sprints_20_min_M1_Tempo.gpx')
    #tree = ET.parse('See_you_later_Winter_welcome_Spring.gpx')
root = tree.getroot()

# %% [markdown]
# each gps device has its own namespace for recording the GPX file... this function reads the embeded namespace

# %%
def namespace(element):
    m = re.match('\{(.*)\}', element.tag)
    return m.group(1) if m else ''

# %%
#url = 'http://vortex.plymouth.edu/cgi-bin/sfc/gen-statlog-a.cgi?ident=cyxu&pl=rawspec&yy=19&mm=04&dd=04&pg=web'
#dialog http://vortex.plymouth.edu/myo/sfc/statlog-a.html
#choose raw hourly & special METAR obs listings
#but only valid for us/cn/mx
#options
#http://www.ogimet.com/metars.phtml.en
#http://www.ogimet.com/display_metars2.php?lang=en&lugar=sbsp&tipo=ALL&ord=REV&nil=SI&fmt=html&ano=2019&mes=04&day=04&hora=00&anof=2019&mesf=04&dayf=04&horaf=23&minf=59&send=send

#https://www.cyclinganalytics.com/

# %%
namespace2 = {'gpx':'http://www.topografix.com/GPX/1/1'}
namespace = {'gpx':namespace(root)}

# %%
#helper functions
def deg2rad(x):
    return x * np.pi / 180

def rad2deg(angle):
    return angle*180/np.pi

def kt2ms(speed):
    return speed * 0.5144444

def ms2kmh(speed):
    return speed * 3.6

# %% [markdown]
# This function calculates the distance and angle between 2 coordinates

# %%
def get_dist_trk(p2, p1):
    #p1 is a list with lat and long in degrees
    #p2 is also a list: lat long
    #returns distance and angle
    #reference: https://www.movable-type.co.uk/scripts/latlong.html
    R = 6371e3 #mean radius of Earth in meters
    phi1 = deg2rad(p1[0])
    phi2 = deg2rad(p2[0])
    lambda1 = deg2rad(p1[1])
    lambda2 = deg2rad(p2[1])
    delta_phi = phi2 - phi1
    delta_lambda = lambda2 - lambda1
    a = np.sin(delta_phi / 2) * np.sin(delta_phi / 2) + \
        np.cos(phi1) * np.cos(phi2) * \
        np.sin(delta_lambda / 2) * np.sin(delta_lambda / 2)
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1-a))
    d = R * c
    y = np.sin(delta_lambda) * np.cos(phi2)
    x = np.cos(phi1) * np.sin(phi2) - \
        np.sin(phi1) * np.cos(phi2) * np.cos(delta_lambda)
    brg = np.arctan2(y,x) * 180 / np.pi
    return d, brg + 180

# %% [markdown]
# Loop through GPX file for each recorded track point and calculate distance and angle

# %%
print('Building track database...')
track = pd.DataFrame(columns=['lat', 'lon', 'elev', 'ts', 'dist', 'true_hdg', 'gs', 'delta_t', 'delta_elev'])
#lat in deg decimal
#lon in deg decimal
#elev in meters
#ts in datetime, tz=0
#dist in meters
#true_hdg in degrees
#gs in m/s
trackpoint = {}
debug_counter = 0
for trk in root.findall('gpx:trk', namespace):
    for trksegmt in trk.findall('gpx:trkseg', namespace):
        first_point = True
        trk_pts_number = len(trksegmt.findall('gpx:trkpt', namespace))
        ten_perc = int(len(trksegmt.findall('gpx:trkpt', namespace)) / 10)
        for idx, trkpoint in enumerate(trksegmt.findall('gpx:trkpt', namespace)):
            if (idx % ten_perc) == 0:
                print('{:0.0f}%... '.format(idx/trk_pts_number*100), end='')
            trackpoint['lat'] = float(trkpoint.get('lat'))
            trackpoint['lon'] = float(trkpoint.get('lon'))
            for elev in trkpoint.findall('gpx:ele', namespace):
                #print(elev.text)
                trackpoint['elev'] = float(elev.text)
            for ts in trkpoint.findall('gpx:time', namespace):
                #print(ts.text)
                trackpoint['ts'] = parser.parse(ts.text)
                
            #garmin extensions
            for extensions in trkpoint.findall('gpx:extensions', namespace):
                #print(extensions)
                for ext in extensions:
                    #print(ext.getchildren())
                    #print(ext.__class__)
                    #print('power is: ', ext.tag, ext.text)
                    if 'power' in ext.tag:
                        print('this is power...', float(ext.text))
                    for child in ext:
                        #print(child.tag)
                        if 'atemp' in child.tag:
                            print('this is the ambient temp:', float(child.text))
                        if 'hr' in child.tag:
                            print('this is the heart rate:', float(child.text))
                        if 'cad' in child.tag:
                            print('this is the cadence:', float(child.text))
                            
                    #print(namespace)
                    #for power in ext.findall('gpx:power', namespace):
                    #    print(namespace,power)
                        #trackpoint['m_power'] = float(power.text)

                
                
            if first_point:
                previous_point = trackpoint
                first_point = False
            dist, angle = get_dist_trk([previous_point['lat'],previous_point['lon']], [trackpoint['lat'],trackpoint['lon']])
            if debug_counter < 20:
                #print(dist, trackpoint['lon'], previous_point['lon'])
                debug_counter += 1
            
            trackpoint['delta_t'] = (trackpoint['ts']-previous_point['ts']).total_seconds()
            trackpoint['dist'] = dist
            trackpoint['true_hdg'] = angle
            if trackpoint['delta_t'] != 0:
                trackpoint['gs'] = dist / trackpoint['delta_t']
            else:
                trackpoint['gs'] = 0
                trackpoint['delta_t'] = np.nan
            trackpoint['delta_elev'] = (trackpoint['elev']-previous_point['elev'])
            previous_point = trackpoint
            track = track.append(trackpoint, ignore_index=True)
            trackpoint = {}
end_time = time.time()
print()
print('Track build time was {:1.1f} seconds'.format(end_time - start_time))
# Out:
# Building track database...
# 0%... this is power... 0.0
# this is the ambient temp: 25.0
# this is the heart rate: 105.0
# this is the cadence: 34.0
# this is power... 0.0
# this is the ambient temp: 25.0
# this is the heart rate: 105.0
# this is the cadence: 34.0
# this is power... 0.0
# this is the ambient temp: 25.0
# this is the heart rate: 105.0
# this is the cadence: 34.0
# this is power... 71.0
# this is the ambient temp: 25.0
# this is the heart rate: 106.0
# this is the cadence: 49.0
# this is power... 54.0
# this is the ambient temp: 25.0
# this is the heart rate: 106.0
# this is the cadence: 56.0
# this is power... 13.0
# this is the ambient temp: 25.0
# this is the heart rate: 107.0
# this is the cadence: 60.0
# this is power... 0.0
# this is the ambient temp: 25.0
# this is the heart rate: 107.0
# this is the cadence: 60.0
# this is power... 0.0
# this is the ambient temp: 25.0
# this is the heart rate: 108.0
# this is the cadence: 60.0
# this is power... 0.0
# this is the ambient temp: 25.0
# this is the heart rate: 108.0
# this is the cadence: 0.0
# this is power... 129.0
# this is the ambient temp: 25.0
# this is the heart rate: 108.0
# this is the cadence: 42.0
# this is power... 169.0
# this is the ambient temp: 25.0
# this is the heart rate: 108.0
# this is the cadence: 67.0
# this is power... 128.0
# this is the ambient temp: 25.0
# this is the heart rate: 109.0
# this is the cadence: 72.0
# this is power... 75.0
# this is the ambient temp: 25.0
# this is the heart rate: 109.0
# this is the cadence: 72.0
# this is power... 75.0
# this is the ambient temp: 25.0
# this is the heart rate: 109.0
# this is the cadence: 72.0
# this is power... 49.0
# this is the ambient temp: 25.0
# this is the heart rate: 110.0
# this is the cadence: 73.0
# this is power... 71.0
# this is the ambient temp: 25.0
# this is the heart rate: 111.0
# this is the cadence: 72.0
# this is power... 79.0
# this is the ambient temp: 25.0
# this is the heart rate: 112.0
# this is the cadence: 71.0
# this is power... 93.0
# this is the ambient temp: 25.0
# this is the heart rate: 113.0
# this is the cadence: 70.0
# this is power... 66.0
# this is the ambient temp: 25.0
# this is the heart rate: 114.0
# this is the cadence: 72.0
# this is power... 103.0
# this is the ambient temp: 25.0
# this is the heart rate: 115.0
# this is the cadence: 71.0
# this is power... 73.0
# this is the ambient temp: 25.0
# this is the heart rate: 116.0
# this is the cadence: 71.0
# this is power... 88.0
# this is the ambient temp: 25.0
# this is the heart rate: 118.0
# this is the cadence: 73.0
# this is power... 162.0
# this is the ambient temp: 25.0
# this is the heart rate: 119.0
# this is the cadence: 72.0
# this is power... 64.0
# this is the ambient temp: 25.0
# this is the heart rate: 120.0
# this is the cadence: 75.0
# this is power... 93.0
# this is the ambient temp: 25.0
# this is the heart rate: 121.0
# this is the cadence: 72.0
# this is power... 110.0
# this is the ambient temp: 25.0
# this is the heart rate: 122.0
# this is the cadence: 74.0
# this is power... 163.0
# this is the ambient temp: 25.0
# this is the heart rate: 123.0
# this is the cadence: 74.0
# this is power... 163.0
# this is the ambient temp: 25.0
# this is the heart rate: 124.0
# this is the cadence: 73.0
# this is power... 158.0
# this is the ambient temp: 25.0
# this is the heart rate: 125.0
# this is the cadence: 72.0
# this is power... 96.0
# this is the ambient temp: 25.0
# this is the heart rate: 126.0
# this is the cadence: 72.0
# this is power... 96.0
# this is the ambient temp: 25.0
# this is the heart rate: 126.0
# this is the cadence: 72.0
# this is power... 99.0
# this is the ambient temp: 25.0
# this is the heart rate: 127.0
# this is the cadence: 73.0
# this is power... 109.0
# this is the ambient temp: 25.0
# this is the heart rate: 128.0
# this is the cadence: 70.0
# this is power... 99.0
# this is the ambient temp: 25.0
# this is the heart rate: 129.0
# this is the cadence: 72.0
# this is power... 135.0
# this is the ambient temp: 25.0
# this is the heart rate: 130.0
# this is the cadence: 73.0
# this is power... 125.0
# this is the ambient temp: 25.0
# this is the heart rate: 130.0
# this is the cadence: 70.0
# this is power... 67.0
# this is the ambient temp: 25.0
# this is the heart rate: 130.0
# this is the cadence: 73.0
# this is power... 52.0
# this is the ambient temp: 25.0
# this is the heart rate: 131.0
# this is the cadence: 73.0
# this is power... 60.0
# this is the ambient temp: 25.0
# this is the heart rate: 131.0
# this is the cadence: 75.0
# this is power... 11.0
# this is the ambient temp: 25.0
# this is the heart rate: 131.0
# this is the cadence: 69.0
# this is power... 0.0
# this is the ambient temp: 25.0
# this is the heart rate: 132.0
# this is the cadence: 69.0
# this is power... 0.0
# this is the ambient temp: 25.0
# this is the heart rate: 132.0
# this is the cadence: 69.0
# this is power... 0.0
# this is the ambient temp: 25.0
# this is the heart rate: 132.0
# this is the cadence: 0.0
# this is power... 0.0
# this is the ambient temp: 25.0
# this is the heart rate: 132.0
# this is the cadence: 0.0
# this is power... 140.0
# this is the ambient temp: 25.0
# this is the heart rate: 133.0
# this is the cadence: 73.0
# this is power... 185.0
# this is the ambient temp: 25.0
# this is the heart rate: 133.0
# this is the cadence: 73.0
# this is power... 185.0
# this is the ambient temp: 25.0
# this is the heart rate: 133.0
# this is the cadence: 73.0
# this is power... 129.0
# this is the ambient temp: 25.0
# this is the heart rate: 133.0
# this is the cadence: 75.0
# this is power... 124.0
# this is the ambient temp: 25.0
# this is the heart rate: 133.0
# this is the cadence: 77.0
# this is power... 125.0
# this is the ambient temp: 25.0
# this is the heart rate: 133.0
# this is the cadence: 78.0
# this is power... 97.0
# this is the ambient temp: 25.0
# this is the heart rate: 133.0
# this is the cadence: 78.0
# this is power... 19.0
# this is the ambient temp: 25.0
# this is the heart rate: 133.0
# this is the cadence: 73.0
# this is power... 31.0
# this is the ambient temp: 25.0
# this is the heart rate: 133.0
# this is the cadence: 73.0
# this is power... 31.0
# this is the ambient temp: 25.0
# this is the heart rate: 133.0
# this is the cadence: 73.0
# this is power... 31.0
# this is the ambient temp: 25.0
# this is the heart rate: 133.0
# this is the cadence: 64.0
# this is power... 47.0
# this is the ambient temp: 25.0
# this is the heart rate: 133.0
# this is the cadence: 73.0
# this is power... 68.0
# this is the ambient temp: 25.0
# this is the heart rate: 132.0
# this is the cadence: 75.0
# this is power... 83.0
# this is the ambient temp: 25.0
# this is the heart rate: 131.0
# this is the cadence: 75.0
# this is power... 49.0
# this is the ambient temp: 25.0
# this is the heart rate: 131.0
# this is the cadence: 76.0
# this is power... 41.0
# this is the ambient temp: 25.0
# this is the heart rate: 130.0
# this is the cadence: 76.0
# this is power... 41.0
# this is the ambient temp: 25.0
# this is the heart rate: 130.0
# this is the cadence: 79.0
# this is power... 39.0
# this is the ambient temp: 25.0
# this is the heart rate: 129.0
# this is the cadence: 79.0
# this is power... 0.0
# this is the ambient temp: 25.0
# this is the heart rate: 129.0
# this is the cadence: 79.0
# this is power... 0.0
# this is the ambient temp: 25.0
# this is the heart rate: 129.0
# this is the cadence: 79.0
# this is power... 0.0
# this is the ambient temp: 25.0
# this is the heart rate: 129.0
# this is the cadence: 0.0
# this is power... 0.0
# this is the ambient temp: 25.0
# this is the heart rate: 130.0
# this is the cadence: 0.0
# this is power... 0.0
# this is the ambient temp: 25.0
# this is the heart rate: 129.0
# this is the cadence: 0.0
# this is power... 0.0
# this is the ambient temp: 25.0
# this is the heart rate: 129.0
# this is the cadence: 0.0
# this is power... 0.0
# this is the ambient temp: 25.0
# this is the heart rate: 127.0
# this is the cadence: 0.0
# this is power... 0.0
# this is the ambient temp: 25.0
# this is the heart rate: 126.0
# this is the cadence: 0.0
# this is power... 0.0
# this is the ambient temp: 25.0
# this is the heart rate: 125.0
# this is the cadence: 0.0
# this is power... 0.0
# this is the ambient temp: 25.0
# this is the heart rate: 123.0
# this is the cadence: 0.0
# this is power... 0.0
# this is the ambient temp: 25.0
# this is the heart rate: 122.0
# this is the cadence: 0.0
# this is power... 0.0
# this is the ambient temp: 25.0
# this is the heart rate: 121.0
# this is the cadence: 0.0
# this is power... 0.0
# this is the ambient temp: 25.0
# this is the heart rate: 120.0
# this is the cadence: 0.0
# this is power... 0.0
# this is the ambient temp: 25.0
# this is the heart rate: 119.0
# this is the cadence: 0.0
# this is power... 0.0
# this is the ambient temp: 25.0
# this is the heart rate: 119.0
# this is the cadence: 0.0
# this is power... 0.0
# this is the ambient temp: 25.0
# this is the heart rate: 119.0
# this is the cadence: 0.0
# this is power... 113.0
# this is the ambient temp: 25.0
# this is the heart rate: 119.0
# this is the cadence: 48.0
# this is power... 0.0
# this is the ambient temp: 25.0
# this is the heart rate: 119.0
# this is the cadence: 48.0
# this is power... 0.0
# this is the ambient temp: 25.0
# this is the heart rate: 120.0
# this is the cadence: 48.0
# this is power... 0.0
# this is the ambient temp: 25.0
# this is the heart rate: 120.0
# this is the cadence: 0.0
# this is power... 0.0
# this is the ambient temp: 25.0
# this is the heart rate: 121.0
# this is the cadence: 0.0
# this is power... 634.0
# this is the ambient temp: 25.0
# this is the heart rate: 122.0
# this is the cadence: 0.0
# this is power... 206.0
# this is the ambient temp: 25.0
# this is the heart rate: 122.0
# this is the cadence: 57.0
# this is power... 182.0
# this is the ambient temp: 25.0
# this is the heart rate: 122.0
# this is the cadence: 63.0
# this is power... 110.0
# this is the ambient temp: 25.0
# this is the heart rate: 123.0
# this is the cadence: 67.0
# this is power... 82.0
# this is the ambient temp: 25.0
# this is the heart rate: 124.0
# this is the cadence: 68.0
# this is power... 112.0
# this is the ambient temp: 25.0
# this is the heart rate: 124.0
# this is the cadence: 75.0
# this is power... 39.0
# this is the ambient temp: 25.0
# this is the heart rate: 125.0
# this is the cadence: 71.0
# this is power... 0.0
# this is the ambient temp: 25.0
# this is the heart rate: 124.0
# this is the cadence: 71.0
# this is power... 0.0
# this is the ambient temp: 25.0
# this is the heart rate: 124.0
# this is the cadence: 0.0
# this is power... 0.0
# this is the ambient temp: 25.0
# this is the heart rate: 123.0
# this is the cadence: 0.0
# this is power... 0.0
# this is the ambient temp: 25.0
# this is the heart rate: 123.0
# this is the cadence: 0.0
# this is power... 0.0
# this is the ambient temp: 25.0
# this is the heart rate: 122.0
# this is the cadence: 0.0
# this is power... 0.0
# this is the ambient temp: 25.0
# this is the heart rate: 121.0
# this is the cadence: 0.0
# this is power... 0.0
# this is the ambient temp: 25.0
# this is the heart rate: 120.0
# this is the cadence: 0.0
# this is power... 149.0
# this is the ambient temp: 25.0
# this is the heart rate: 120.0
# this is the cadence: 85.0
# this is power... 182.0
# this is the ambient temp: 25.0
# this is the heart rate: 121.0
# this is the cadence: 79.0
# this is power... 257.0
# this is the ambient temp: 25.0
# this is the heart rate: 121.0
# this is the cadence: 77.0
# this is power... 173.0
# this is the ambient temp: 25.0
# this is the heart rate: 122.0
# this is the cadence: 81.0
# this is power... 192.0
# this is the ambient temp: 25.0
# this is the heart rate: 124.0
# this is the cadence: 78.0
# this is power... 185.0
# this is the ambient temp: 25.0
# this is the heart rate: 125.0
# this is the cadence: 79.0
# this is power... 189.0
# this is the ambient temp: 25.0
# this is the heart rate: 125.0
# this is the cadence: 77.0
# this is power... 159.0
# this is the ambient temp: 25.0
# this is the heart rate: 126.0
# this is the cadence: 78.0
# this is power... 203.0
# this is the ambient temp: 25.0
# this is the heart rate: 127.0
# this is the cadence: 76.0
# this is power... 235.0
# this is the ambient temp: 25.0
# this is the heart rate: 127.0
# this is the cadence: 77.0
# this is power... 188.0
# this is the ambient temp: 25.0
# this is the heart rate: 127.0
# this is the cadence: 76.0
# this is power... 199.0
# this is the ambient temp: 25.0
# this is the heart rate: 128.0
# this is the cadence: 76.0
# this is power... 177.0
# this is the ambient temp: 25.0
# this is the heart rate: 128.0
# this is the cadence: 75.0
# this is power... 197.0
# this is the ambient temp: 25.0
# this is the heart rate: 128.0
# this is the cadence: 75.0
# this is power... 212.0
# this is the ambient temp: 25.0
# this is the heart rate: 129.0
# this is the cadence: 73.0
# this is power... 218.0
# this is the ambient temp: 25.0
# this is the heart rate: 129.0
# this is the cadence: 74.0
# this is power... 234.0
# this is the ambient temp: 25.0
# this is the heart rate: 130.0
# this is the cadence: 74.0
# this is power... 234.0
# this is the ambient temp: 25.0
# this is the heart rate: 131.0
# this is the cadence: 73.0
# this is power... 188.0
# this is the ambient temp: 25.0
# this is the heart rate: 132.0
# this is the cadence: 73.0
# this is power... 211.0
# this is the ambient temp: 25.0
# this is the heart rate: 133.0
# this is the cadence: 72.0
# this is power... 222.0
# this is the ambient temp: 25.0
# this is the heart rate: 133.0
# this is the cadence: 71.0
# this is power... 229.0
# this is the ambient temp: 25.0
# this is the heart rate: 134.0
# this is the cadence: 72.0
# this is power... 239.0
# this is the ambient temp: 25.0
# this is the heart rate: 134.0
# this is the cadence: 72.0
# this is power... 232.0
# this is the ambient temp: 25.0
# this is the heart rate: 135.0
# this is the cadence: 73.0
# this is power... 221.0
# this is the ambient temp: 25.0
# this is the heart rate: 135.0
# this is the cadence: 72.0
# this is power... 224.0
# this is the ambient temp: 25.0
# this is the heart rate: 136.0
# this is the cadence: 72.0
# this is power... 238.0
# this is the ambient temp: 25.0
# this is the heart rate: 136.0
# this is the cadence: 71.0
# this is power... 238.0
# this is the ambient temp: 25.0
# this is the heart rate: 137.0
# this is the cadence: 71.0
# this is power... 222.0
# this is the ambient temp: 25.0
# this is the heart rate: 138.0
# this is the cadence: 71.0
# this is power... 222.0
# this is the ambient temp: 25.0
# this is the heart rate: 139.0
# this is the cadence: 71.0
# this is power... 235.0
# this is the ambient temp: 25.0
# this is the heart rate: 139.0
# this is the cadence: 71.0
# this is power... 195.0
# this is the ambient temp: 25.0
# this is the heart rate: 140.0
# this is the cadence: 71.0
# this is power... 205.0
# this is the ambient temp: 25.0
# this is the heart rate: 140.0
# this is the cadence: 71.0
# this is power... 190.0
# this is the ambient temp: 25.0
# this is the heart rate: 141.0
# this is the cadence: 70.0
# this is power... 193.0
# this is the ambient temp: 25.0
# this is the heart rate: 142.0
# this is the cadence: 74.0
# this is power... 147.0
# this is the ambient temp: 25.0
# this is the heart rate: 143.0
# this is the cadence: 75.0
# this is power... 141.0
# this is the ambient temp: 25.0
# this is the heart rate: 143.0
# this is the cadence: 74.0
# this is power... 186.0
# this is the ambient temp: 25.0
# this is the heart rate: 143.0
# this is the cadence: 74.0
# this is power... 187.0
# this is the ambient temp: 25.0
# this is the heart rate: 144.0
# this is the cadence: 70.0
# this is power... 180.0
# this is the ambient temp: 25.0
# this is the heart rate: 144.0
# this is the cadence: 72.0
# this is power... 138.0
# this is the ambient temp: 25.0
# this is the heart rate: 145.0
# this is the cadence: 73.0
# this is power... 145.0
# this is the ambient temp: 25.0
# this is the heart rate: 145.0
# this is the cadence: 72.0
# this is power... 158.0
# this is the ambient temp: 25.0
# this is the heart rate: 146.0
# this is the cadence: 71.0
# this is power... 116.0
# this is the ambient temp: 25.0
# this is the heart rate: 146.0
# this is the cadence: 71.0
# this is power... 116.0
# this is the ambient temp: 25.0
# this is the heart rate: 146.0
# this is the cadence: 71.0
# this is power... 116.0
# this is the ambient temp: 25.0
# this is the heart rate: 146.0
# this is the cadence: 71.0
# this is power... 100.0
# this is the ambient temp: 25.0
# this is the heart rate: 147.0
# this is the cadence: 72.0
# this is power... 114.0
# this is the ambient temp: 25.0
# this is the heart rate: 147.0
# this is the cadence: 71.0
# this is power... 108.0
# this is the ambient temp: 25.0
# this is the heart rate: 147.0
# this is the cadence: 70.0
# this is power... 104.0
# this is the ambient temp: 25.0
# this is the heart rate: 147.0
# this is the cadence: 70.0
# this is power... 99.0
# this is the ambient temp: 25.0
# this is the heart rate: 147.0
# this is the cadence: 69.0
# this is power... 121.0
# this is the ambient temp: 25.0
# this is the heart rate: 148.0
# this is the cadence: 68.0
# this is power... 130.0
# this is the ambient temp: 25.0
# this is the heart rate: 148.0
# this is the cadence: 68.0
# this is power... 122.0
# this is the ambient temp: 25.0
# this is the heart rate: 148.0
# this is the cadence: 67.0
# this is power... 133.0
# this is the ambient temp: 25.0
# this is the heart rate: 148.0
# this is the cadence: 67.0
# this is power... 129.0
# this is the ambient temp: 25.0
# this is the heart rate: 149.0
# this is the cadence: 67.0
# this is power... 130.0
# this is the ambient temp: 25.0
# this is the heart rate: 149.0
# this is the cadence: 69.0
# this is power... 124.0
# this is the ambient temp: 25.0
# this is the heart rate: 149.0
# this is the cadence: 69.0
# this is power... 124.0
# this is the ambient temp: 25.0
# this is the heart rate: 149.0
# this is the cadence: 70.0
# this is power... 175.0
# this is the ambient temp: 25.0
# this is the heart rate: 149.0
# this is the cadence: 70.0
# this is power... 129.0
# this is the ambient temp: 25.0
# this is the heart rate: 149.0
# this is the cadence: 69.0
# this is power... 133.0
# this is the ambient temp: 25.0
# this is the heart rate: 149.0
# this is the cadence: 68.0
# this is power... 127.0
# this is the ambient temp: 25.0
# this is the heart rate: 149.0
# this is the cadence: 67.0
# this is power... 132.0
# this is the ambient temp: 25.0
# this is the heart rate: 150.0
# this is the cadence: 68.0
# this is power... 149.0
# this is the ambient temp: 25.0
# this is the heart rate: 150.0
# this is the cadence: 67.0
# this is power... 134.0
# this is the ambient temp: 25.0
# this is the heart rate: 150.0
# this is the cadence: 67.0
# this is power... 115.0
# this is the ambient temp: 25.0
# this is the heart rate: 151.0
# this is the cadence: 68.0
# this is power... 156.0
# this is the ambient temp: 25.0
# this is the heart rate: 151.0
# this is the cadence: 64.0
# this is power... 172.0
# this is the ambient temp: 25.0
# this is the heart rate: 151.0
# this is the cadence: 66.0
# this is power... 203.0
# this is the ambient temp: 25.0
# this is the heart rate: 152.0
# this is the cadence: 67.0
# this is power... 187.0
# this is the ambient temp: 25.0
# this is the heart rate: 152.0
# this is the cadence: 71.0
# this is power... 127.0
# this is the ambient temp: 25.0
# this is the heart rate: 152.0
# this is the cadence: 72.0
# this is power... 164.0
# this is the ambient temp: 25.0
# this is the heart rate: 152.0
# this is the cadence: 72.0
# this is power... 164.0
# this is the ambient temp: 25.0
# this is the heart rate: 152.0
# this is the cadence: 72.0
# this is power... 213.0
# this is the ambient temp: 25.0
# this is the heart rate: 152.0
# this is the cadence: 72.0
# this is power... 213.0
# this is the ambient temp: 25.0
# this is the heart rate: 153.0
# this is the cadence: 71.0
# this is power... 248.0
# this is the ambient temp: 25.0
# this is the heart rate: 153.0
# this is the cadence: 69.0
# this is power... 218.0
# this is the ambient temp: 25.0
# this is the heart rate: 153.0
# this is the cadence: 72.0
# this is power... 337.0
# this is the ambient temp: 25.0
# this is the heart rate: 153.0
# this is the cadence: 69.0
# this is power... 247.0
# this is the ambient temp: 25.0
# this is the heart rate: 153.0
# this is the cadence: 73.0
# this is power... 309.0
# this is the ambient temp: 25.0
# this is the heart rate: 153.0
# this is the cadence: 72.0
# this is power... 212.0
# this is the ambient temp: 25.0
# this is the heart rate: 154.0
# this is the cadence: 73.0
# this is power... 228.0
# this is the ambient temp: 25.0
# this is the heart rate: 154.0
# this is the cadence: 72.0
# this is power... 227.0
# this is the ambient temp: 25.0
# this is the heart rate: 154.0
# this is the cadence: 73.0
# this is power... 249.0
# this is the ambient temp: 25.0
# this is the heart rate: 154.0
# this is the cadence: 72.0
# this is power... 208.0
# this is the ambient temp: 25.0
# this is the heart rate: 154.0
# this is the cadence: 72.0
# this is power... 312.0
# this is the ambient temp: 25.0
# this is the heart rate: 154.0
# this is the cadence: 71.0
# this is power... 206.0
# this is the ambient temp: 25.0
# this is the heart rate: 155.0
# this is the cadence: 74.0
# this is power... 224.0
# this is the ambient temp: 25.0
# this is the heart rate: 154.0
# this is the cadence: 73.0
# this is power... 212.0
# this is the ambient temp: 25.0
# this is the heart rate: 154.0
# this is the cadence: 72.0
# this is power... 205.0
# this is the ambient temp: 25.0
# this is the heart rate: 155.0
# this is the cadence: 73.0
# this is power... 204.0
# this is the ambient temp: 25.0
# this is the heart rate: 154.0
# this is the cadence: 72.0
# this is power... 223.0
# this is the ambient temp: 25.0
# this is the heart rate: 154.0
# this is the cadence: 73.0
# this is power... 301.0
# this is the ambient temp: 25.0
# this is the heart rate: 154.0
# this is the cadence: 69.0
# this is power... 196.0
# this is the ambient temp: 25.0
# this is the heart rate: 154.0
# this is the cadence: 77.0
# this is power... 223.0
# this is the ambient temp: 25.0
# this is the heart rate: 155.0
# this is the cadence: 74.0
# this is power... 209.0
# this is the ambient temp: 25.0
# this is the heart rate: 154.0
# this is the cadence: 75.0
# this is power... 288.0
# this is the ambient temp: 25.0
# this is the heart rate: 154.0
# this is the cadence: 72.0
# this is power... 180.0
# this is the ambient temp: 25.0
# this is the heart rate: 154.0
# this is the cadence: 76.0
# this is power... 193.0
# this is the ambient temp: 25.0
# this is the heart rate: 154.0
# this is the cadence: 73.0
# this is power... 204.0
# this is the ambient temp: 25.0
# this is the heart rate: 154.0
# this is the cadence: 74.0
# this is power... 224.0
# this is the ambient temp: 25.0
# this is the heart rate: 154.0
# this is the cadence: 73.0
# this is power... 288.0
# this is the ambient temp: 25.0
# this is the heart rate: 154.0
# this is the cadence: 74.0
# this is power... 234.0
# this is the ambient temp: 25.0
# this is the heart rate: 154.0
# this is the cadence: 74.0
# this is power... 227.0
# this is the ambient temp: 25.0
# this is the heart rate: 154.0
# this is the cadence: 75.0
# this is power... 233.0
# this is the ambient temp: 25.0
# this is the heart rate: 154.0
# this is the cadence: 75.0
# this is power... 179.0
# this is the ambient temp: 25.0
# this is the heart rate: 154.0
# this is the cadence: 78.0
# this is power... 240.0
# this is the ambient temp: 25.0
# this is the heart rate: 154.0
# this is the cadence: 72.0
# this is power... 239.0
# this is the ambient temp: 25.0
# this is the heart rate: 154.0
# this is the cadence: 73.0
# this is power... 295.0
# this is the ambient temp: 25.0
# this is the heart rate: 155.0
# this is the cadence: 73.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-644d6bc0d4a6> in <module>
#      70             trackpoint['delta_elev'] = (trackpoint['elev']-previous_point['elev'])
#      71             previous_point = trackpoint
# ---> 72             track = track.append(trackpoint, ignore_index=True)
#      73             trackpoint = {}
#      74 end_time = time.time()
#
# ~/miniconda3/envs/gpx1/lib/python3.8/site-packages/pandas/core/frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    7079         else:
#    7080             to_concat = [self, other]
# -> 7081         return concat(
#    7082             to_concat,
#    7083             ignore_index=ignore_index,
#
# ~/miniconda3/envs/gpx1/lib/python3.8/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     282     )
#     283
# --> 284     return op.get_result()
#     285
#     286
#
# ~/miniconda3/envs/gpx1/lib/python3.8/site-packages/pandas/core/reshape/concat.py in get_result(self)
#     494                 mgrs_indexers.append((obj._data, indexers))
#     495
# --> 496             new_data = concatenate_block_managers(
#     497                 mgrs_indexers, self.new_axes, concat_axis=self.axis, copy=self.copy
#     498             )
#
# ~/miniconda3/envs/gpx1/lib/python3.8/site-packages/pandas/core/internals/managers.py in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#    2020         else:
#    2021             b = make_block(
# -> 2022                 concatenate_join_units(join_units, concat_axis, copy=copy),
#    2023                 placement=placement,
#    2024             )
#
# ~/miniconda3/envs/gpx1/lib/python3.8/site-packages/pandas/core/internals/concat.py in concatenate_join_units(join_units, concat_axis, copy)
#     244     empty_dtype, upcasted_na = _get_empty_dtype_and_na(join_units)
#     245
# --> 246     to_concat = [
#     247         ju.get_reindexed_values(empty_dtype=empty_dtype, upcasted_na=upcasted_na)
#     248         for ju in join_units
#
# ~/miniconda3/envs/gpx1/lib/python3.8/site-packages/pandas/core/internals/concat.py in <listcomp>(.0)
#     245
#     246     to_concat = [
# --> 247         ju.get_reindexed_values(empty_dtype=empty_dtype, upcasted_na=upcasted_na)
#     248         for ju in join_units
#     249     ]
#
# ~/miniconda3/envs/gpx1/lib/python3.8/site-packages/pandas/core/internals/concat.py in get_reindexed_values(self, empty_dtype, upcasted_na)
#     219                 # No dtype upcasting is done here, it will be performed during
#     220                 # concatenation itself.
# --> 221                 values = self.block.get_values()
#     222
#     223         if not self.indexers:
#
# ~/miniconda3/envs/gpx1/lib/python3.8/site-packages/pandas/core/internals/blocks.py in get_values(self, dtype)
#     228         this is often overridden to handle to_dense like operations
#     229         """
# --> 230         if is_object_dtype(dtype):
#     231             return self.values.astype(object)
#     232         return self.values
#
# ~/miniconda3/envs/gpx1/lib/python3.8/site-packages/pandas/core/dtypes/common.py in is_object_dtype(arr_or_dtype)
#     247     False
#     248     """
# --> 249     return _is_dtype_type(arr_or_dtype, classes(np.object_))
#     250
#     251
#
# ~/miniconda3/envs/gpx1/lib/python3.8/site-packages/pandas/core/dtypes/common.py in _is_dtype_type(arr_or_dtype, condition)
#    1722
#    1723     if arr_or_dtype is None:
# -> 1724         return condition(type(None))
#    1725
#    1726     # fastpath
#
# KeyboardInterrupt:

# %%
from bs4 import BeautifulSoup

data = """<?xml version="1.0" encoding="UTF-8"?>
<note>
    <to> Tove</to>
    <from>Jani</from>
    <heading>Reminder</heading>
    <body>Don't forget me this weekend!</body>
</note>
"""

soup = BeautifulSoup('./sample_data/S4_Form_Sprints_20_min_M1_Tempo.gpx', 'xml')
print [tag.name for tag in soup.find_all()]
